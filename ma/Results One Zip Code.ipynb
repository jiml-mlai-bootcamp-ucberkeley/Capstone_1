# %%
import pandas as pd

# %%
decision_tree_df = pd.DataFrame({'model': ['Decision Tree Best Params',
  'Recursive Feature Elimination',
  'Sequential Feature Selector'],
 'explained variance score': ['0.397918613', '0.397918613', '0.411193064'],
 'mae score': ['204,500.000000', '204,500.000000', '233,500.000000'],
 'mse score': ['106,688,833,333.333328',
  '106,688,833,333.333328',
  '93,894,833,333.333328'],
 'r2 score': ['0.049081', '0.049081', '0.163114'],
 'mean fit time': [0.00052947998046875,
  0.0013878822326660156,
  0.002211189270019531]}).set_index('model')

# %%
knn_df = pd.DataFrame({'model': ['KNN Best Params', 'Sequential Feature Selector'],
 'explained variance score': ['0.379466690', '0.332167653'],
 'mae score': ['239,055.555556', '260,233.333333'],
 'mse score': ['106,805,722,222.222229', '131,682,886,666.666672'],
 'r2 score': ['0.048039', '-0.173692'],
 'mean fit time': [0.0018405437469482422, 0.000194549560546875]}).set_index('model')

# %%
lasso_df = pd.DataFrame({'model': ['Lasso Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination'],
 'explained variance score': ['0.722211577',
  '0.040543442',
  '0.732355225',
  '0.040543442'],
 'mae score': ['139,346.900073',
  '309,976.997844',
  '135,490.252806',
  '309,976.997844'],
 'mse score': ['34,207,400,479.922718',
  '117,436,699,657.530197',
  '33,387,642,010.595226',
  '117,436,699,657.530197'],
 'r2 score': ['0.695109', '-0.046715', '0.702415', '-0.046715'],
 'mean fit time': [0.0001544952392578125,
  0.0018259048461914062,
  0.003058338165283203,
  0.0023864269256591796]}).set_index('model')

# %%
linear_df = pd.DataFrame({'model': ['Linear Regression',
  'Recursive Feature Elimination',
  'Sequential Feature Selector',
  'Select From Model',
  'Polynomial Features'],
 'explained variance score': ['0.666524546',
  '0.009311623',
  '0.666235813',
  '0.009311623',
  '0.678416304'],
 'mae score': ['162,479.931443',
  '315,441.623106',
  '160,647.206528',
  '315,441.623106',
  '158,404.295765'],
 'mse score': ['40,134,382,207.780304',
  '120,207,665,746.763504',
  '40,374,469,215.238701',
  '120,207,665,746.763504',
  '39,134,925,847.592827'],
 'r2 score': ['0.642282', '-0.071413', '0.640142', '-0.071413', '0.651190'],
 'mean fit time': [0.0016257286071777344,
  0.0018158435821533203,
  0.0018278598785400391,
  0.0020148754119873047,
  0.0]}).set_index('model')

# %%
ridge_df = pd.DataFrame({'model': ['Ridge Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination'],
 'explained variance score': ['0.708134530',
  '0.109790087',
  '0.702583296',
  '0.109790087'],
 'mae score': ['144,137.211300',
  '291,933.082296',
  '147,266.128498',
  '291,933.082296'],
 'mse score': ['36,105,212,599.929771',
  '126,769,196,633.604797',
  '36,346,560,328.843964',
  '126,769,196,633.604797'],
 'r2 score': ['0.678194', '-0.129896', '0.676043', '-0.129896'],
 'mean fit time': [0.001119089126586914, 0.0, 0.0, 0.0013049125671386718]}).set_index('model')

# %%
decision_tree_df
# Out:
#                               explained variance score       mae score  \
# model
# Decision Tree Best Params                  0.397918613  204,500.000000
# Recursive Feature Elimination              0.397918613  204,500.000000
# Sequential Feature Selector                0.411193064  233,500.000000
#
#                                             mse score  r2 score  mean fit time
# model
# Decision Tree Best Params      106,688,833,333.333328  0.049081       0.000529
# Recursive Feature Elimination  106,688,833,333.333328  0.049081       0.001388
# Sequential Feature Selector     93,894,833,333.333328  0.163114       0.002211

# %%
knn_df
# Out:
#                             explained variance score       mae score  \
# model
# KNN Best Params                          0.379466690  239,055.555556
# Sequential Feature Selector              0.332167653  260,233.333333
#
#                                           mse score   r2 score  mean fit time
# model
# KNN Best Params              106,805,722,222.222229   0.048039       0.001841
# Sequential Feature Selector  131,682,886,666.666672  -0.173692       0.000195

# %%
lasso_df
# Out:
#                               explained variance score       mae score  \
# model
# Lasso Best Params                          0.722211577  139,346.900073
# Select From Model                          0.040543442  309,976.997844
# Sequential Feature Selector                0.732355225  135,490.252806
# Recursive Feature Elimination              0.040543442  309,976.997844
#
#                                             mse score   r2 score  \
# model
# Lasso Best Params               34,207,400,479.922718   0.695109
# Select From Model              117,436,699,657.530197  -0.046715
# Sequential Feature Selector     33,387,642,010.595226   0.702415
# Recursive Feature Elimination  117,436,699,657.530197  -0.046715
#
#                                mean fit time
# model
# Lasso Best Params                   0.000154
# Select From Model                   0.001826
# Sequential Feature Selector         0.003058
# Recursive Feature Elimination       0.002386

# %%
linear_df
# Out:
#                               explained variance score       mae score  \
# model
# Linear Regression                          0.666524546  162,479.931443
# Recursive Feature Elimination              0.009311623  315,441.623106
# Sequential Feature Selector                0.666235813  160,647.206528
# Select From Model                          0.009311623  315,441.623106
# Polynomial Features                        0.678416304  158,404.295765
#
#                                             mse score   r2 score  \
# model
# Linear Regression               40,134,382,207.780304   0.642282
# Recursive Feature Elimination  120,207,665,746.763504  -0.071413
# Sequential Feature Selector     40,374,469,215.238701   0.640142
# Select From Model              120,207,665,746.763504  -0.071413
# Polynomial Features             39,134,925,847.592827   0.651190
#
#                                mean fit time
# model
# Linear Regression                   0.001626
# ...

# %%
ridge_df
# Out:
#                               explained variance score       mae score  \
# model
# Ridge Best Params                          0.708134530  144,137.211300
# Select From Model                          0.109790087  291,933.082296
# Sequential Feature Selector                0.702583296  147,266.128498
# Recursive Feature Elimination              0.109790087  291,933.082296
#
#                                             mse score   r2 score  \
# model
# Ridge Best Params               36,105,212,599.929771   0.678194
# Select From Model              126,769,196,633.604797  -0.129896
# Sequential Feature Selector     36,346,560,328.843964   0.676043
# Recursive Feature Elimination  126,769,196,633.604797  -0.129896
#
#                                mean fit time
# model
# Ridge Best Params                   0.001119
# Select From Model                   0.000000
# Sequential Feature Selector         0.000000
# Recursive Feature Elimination       0.001305
