# %%
import pandas as pd

# %%
decision_tree_df = pd.DataFrame({'model': ['Decision Tree Best Params',
  'Recursive Feature Elimination',
  'Sequential Feature Selector'],
 'explained variance score': ['0.661461418', '0.832403592', '0.782233403'],
 'mae score': ['530,364.125397', '423,355.577778', '471,527.001058'],
 'mse score': ['747,909,920,375.919312',
  '370,211,522,923.479004',
  '475,785,667,513.888428'],
 'r2 score': ['0.645625', '0.824586', '0.774563'],
 'mean fit time': [0.001764678955078125,
  0.002796792984008789,
  0.0002106189727783203]}).set_index('model')

# %%
knn_df = pd.DataFrame({'model': ['KNN Best Params', 'Sequential Feature Selector'],
 'explained variance score': ['0.810248470', '0.804406033'],
 'mae score': ['444,470.392593', '450,147.422222'],
 'mse score': ['402,898,591,288.911133', '416,996,986,572.533325'],
 'r2 score': ['0.809098', '0.802418'],
 'mean fit time': [0.0, 0.0031032562255859375]}).set_index('model')

# %%
lasso_df = pd.DataFrame({'model': ['Lasso Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination'],
 'explained variance score': ['0.795335493',
  '0.719282250',
  '0.789569061',
  '0.719282250'],
 'mae score': ['508,399.145132',
  '532,504.688216',
  '514,162.138120',
  '532,504.688216'],
 'mse score': ['456,541,845,098.999817',
  '606,896,770,133.040771',
  '469,450,784,973.096680',
  '606,896,770,133.040771'],
 'r2 score': ['0.783681', '0.712440', '0.777564', '0.712440'],
 'mean fit time': [0.0015205860137939454, 0.0, 0.0, 0.0]}).set_index('model')

# %%
linear_df = pd.DataFrame({'model': ['Linear Regression',
  'Recursive Feature Elimination',
  'Sequential Feature Selector',
  'Select From Model',
  'Polynomial Features'],
 'explained variance score': ['0.788089206',
  '0.721477473',
  '0.788488878',
  '0.788089206',
  '0.789107377'],
 'mae score': ['517,273.760030',
  '533,228.997013',
  '518,182.376911',
  '517,273.760030',
  '513,595.529469'],
 'mse score': ['471,658,109,139.970764',
  '602,436,849,966.523315',
  '471,737,273,778.858765',
  '471,658,109,139.970764',
  '469,319,940,360.606689'],
 'r2 score': ['0.776519', '0.714553', '0.776481', '0.776519', '0.777626'],
 'mean fit time': [0.0049155235290527345,
  0.0017600536346435546,
  0.001495695114135742,
  0.0022457599639892577,
  0.0]}).set_index('model')

# %%
ridge_df = pd.DataFrame({'model': ['Ridge Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination'],
 'explained variance score': ['0.794808775',
  '0.722973414',
  '0.794072275',
  '0.722973414'],
 'mae score': ['508,560.989610',
  '526,975.340683',
  '510,025.686650',
  '526,975.340683'],
 'mse score': ['457,520,665,251.461365',
  '599,007,585,507.179810',
  '459,914,830,624.804321',
  '599,007,585,507.179810'],
 'r2 score': ['0.783217', '0.716178', '0.782083', '0.716178'],
 'mean fit time': [0.0010103225708007813,
  0.002499103546142578,
  0.0038625717163085936,
  0.002575397491455078]}).set_index('model')

# %%
decision_tree_df
# Out:
#                               explained variance score       mae score  \
# model
# Decision Tree Best Params                  0.661461418  530,364.125397
# Recursive Feature Elimination              0.832403592  423,355.577778
# Sequential Feature Selector                0.782233403  471,527.001058
#
#                                             mse score  r2 score  mean fit time
# model
# Decision Tree Best Params      747,909,920,375.919312  0.645625       0.001765
# Recursive Feature Elimination  370,211,522,923.479004  0.824586       0.002797
# Sequential Feature Selector    475,785,667,513.888428  0.774563       0.000211

# %%
knn_df
# Out:
#                             explained variance score       mae score  \
# model
# KNN Best Params                          0.810248470  444,470.392593
# Sequential Feature Selector              0.804406033  450,147.422222
#
#                                           mse score  r2 score  mean fit time
# model
# KNN Best Params              402,898,591,288.911133  0.809098       0.000000
# Sequential Feature Selector  416,996,986,572.533325  0.802418       0.003103

# %%
lasso_df
# Out:
#                               explained variance score       mae score  \
# model
# Lasso Best Params                          0.795335493  508,399.145132
# Select From Model                          0.719282250  532,504.688216
# Sequential Feature Selector                0.789569061  514,162.138120
# Recursive Feature Elimination              0.719282250  532,504.688216
#
#                                             mse score  r2 score  mean fit time
# model
# Lasso Best Params              456,541,845,098.999817  0.783681       0.001521
# Select From Model              606,896,770,133.040771  0.712440       0.000000
# Sequential Feature Selector    469,450,784,973.096680  0.777564       0.000000
# Recursive Feature Elimination  606,896,770,133.040771  0.712440       0.000000

# %%
linear_df
# Out:
#                               explained variance score       mae score  \
# model
# Linear Regression                          0.788089206  517,273.760030
# Recursive Feature Elimination              0.721477473  533,228.997013
# Sequential Feature Selector                0.788488878  518,182.376911
# Select From Model                          0.788089206  517,273.760030
# Polynomial Features                        0.789107377  513,595.529469
#
#                                             mse score  r2 score  mean fit time
# model
# Linear Regression              471,658,109,139.970764  0.776519       0.004916
# Recursive Feature Elimination  602,436,849,966.523315  0.714553       0.001760
# Sequential Feature Selector    471,737,273,778.858765  0.776481       0.001496
# Select From Model              471,658,109,139.970764  0.776519       0.002246
# Polynomial Features            469,319,940,360.606689  0.777626       0.000000

# %%
ridge_df
# Out:
#                               explained variance score       mae score  \
# model
# Ridge Best Params                          0.794808775  508,560.989610
# Select From Model                          0.722973414  526,975.340683
# Sequential Feature Selector                0.794072275  510,025.686650
# Recursive Feature Elimination              0.722973414  526,975.340683
#
#                                             mse score  r2 score  mean fit time
# model
# Ridge Best Params              457,520,665,251.461365  0.783217       0.001010
# Select From Model              599,007,585,507.179810  0.716178       0.002499
# Sequential Feature Selector    459,914,830,624.804321  0.782083       0.003863
# Recursive Feature Elimination  599,007,585,507.179810  0.716178       0.002575
