# %%
import pandas as pd

# %%
decision_tree_df = pd.DataFrame({'model': ['Decision Tree Best Params',
  'Recursive Feature Elimination',
  'Sequential Feature Selector'],
 'explained variance score': ['-0.192776440', '-0.864360536', '-0.820143143'],
 'mae score': ['200,031.924423', '198,744.512195', '219,359.361789'],
 'mse score': ['66,647,535,692.692680',
  '99,253,568,104.365860',
  '98,505,129,824.962738'],
 'r2 score': ['-0.273592', '-0.896672', '-0.882370'],
 'mean fit time': [0.0025202274322509766,
  0.003040933609008789,
  0.002519369125366211]}).set_index('model')

# %%
knn_df = pd.DataFrame({'model': ['KNN Best Params', 'Sequential Feature Selector'],
 'explained variance score': ['0.177799239', '-0.019271769'],
 'mae score': ['144,550.349593', '148,147.936585'],
 'mse score': ['43,690,700,473.990677', '53,918,140,825.950241'],
 'r2 score': ['0.165099', '-0.030341'],
 'mean fit time': [0.0024251461029052733, 0.0025281429290771483]}).set_index('model')

# %%
lasso_df = pd.DataFrame({'model': ['Lasso Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination'],
 'explained variance score': ['0.217242655',
  '0.253935298',
  '0.216728901',
  '0.253935298'],
 'mae score': ['148,626.068763',
  '157,213.464145',
  '151,052.598678',
  '157,213.464145'],
 'mse score': ['43,845,866,015.632065',
  '40,926,076,228.723534',
  '44,043,445,535.560242',
  '40,926,076,228.723534'],
 'r2 score': ['0.162134', '0.217929', '0.158358', '0.217929'],
 'mean fit time': [0.0017444610595703125, 0.0, 0.0, 0.0]}).set_index('model')

# %%
linear_df = pd.DataFrame({'model': ['Linear Regression',
  'Recursive Feature Elimination',
  'Sequential Feature Selector',
  'Select From Model',
  'Polynomial Features'],
 'explained variance score': ['0.314659875',
  '0.274799595',
  '0.287904664',
  '0.327070359',
  '0.279349671'],
 'mae score': ['145,007.322709',
  '154,207.951943',
  '145,506.203358',
  '148,464.291769',
  '149,037.013140'],
 'mse score': ['38,800,128,783.702110',
  '39,877,367,403.767944',
  '40,103,828,511.706619',
  '37,708,337,947.386711',
  '40,550,633,780.777458'],
 'r2 score': ['0.258554', '0.237969', '0.233642', '0.279418', '0.225103'],
 'mean fit time': [0.004758405685424805,
  0.0016360759735107421,
  0.0030110836029052734,
  0.002059650421142578,
  0.0009041786193847656]}).set_index('model')

# %%
ridge_df = pd.DataFrame({'model': ['Ridge Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination'],
 'explained variance score': ['0.250788002',
  '0.335361932',
  '0.176598345',
  '0.335361932'],
 'mae score': ['149,461.433501',
  '148,574.479146',
  '152,551.269275',
  '148,574.479146'],
 'mse score': ['41,951,877,693.373276',
  '37,025,986,127.903168',
  '46,009,427,143.237213',
  '37,025,986,127.903168'],
 'r2 score': ['0.198327', '0.292457', '0.120789', '0.292457'],
 'mean fit time': [0.0, 0.0, 0.0013040065765380859, 0.0]}).set_index('model')

# %%
decision_tree_df
# Out:
#                               explained variance score       mae score  \
# model
# Decision Tree Best Params                 -0.192776440  200,031.924423
# Recursive Feature Elimination             -0.864360536  198,744.512195
# Sequential Feature Selector               -0.820143143  219,359.361789
#
#                                            mse score   r2 score  mean fit time
# model
# Decision Tree Best Params      66,647,535,692.692680  -0.273592       0.002520
# Recursive Feature Elimination  99,253,568,104.365860  -0.896672       0.003041
# Sequential Feature Selector    98,505,129,824.962738  -0.882370       0.002519

# %%
knn_df
# Out:
#                             explained variance score       mae score  \
# model
# KNN Best Params                          0.177799239  144,550.349593
# Sequential Feature Selector             -0.019271769  148,147.936585
#
#                                          mse score   r2 score  mean fit time
# model
# KNN Best Params              43,690,700,473.990677   0.165099       0.002425
# Sequential Feature Selector  53,918,140,825.950241  -0.030341       0.002528

# %%
lasso_df
# Out:
#                               explained variance score       mae score  \
# model
# Lasso Best Params                          0.217242655  148,626.068763
# Select From Model                          0.253935298  157,213.464145
# Sequential Feature Selector                0.216728901  151,052.598678
# Recursive Feature Elimination              0.253935298  157,213.464145
#
#                                            mse score  r2 score  mean fit time
# model
# Lasso Best Params              43,845,866,015.632065  0.162134       0.001744
# Select From Model              40,926,076,228.723534  0.217929       0.000000
# Sequential Feature Selector    44,043,445,535.560242  0.158358       0.000000
# Recursive Feature Elimination  40,926,076,228.723534  0.217929       0.000000

# %%
linear_df
# Out:
#                               explained variance score       mae score  \
# model
# Linear Regression                          0.314659875  145,007.322709
# Recursive Feature Elimination              0.274799595  154,207.951943
# Sequential Feature Selector                0.287904664  145,506.203358
# Select From Model                          0.327070359  148,464.291769
# Polynomial Features                        0.279349671  149,037.013140
#
#                                            mse score  r2 score  mean fit time
# model
# Linear Regression              38,800,128,783.702110  0.258554       0.004758
# Recursive Feature Elimination  39,877,367,403.767944  0.237969       0.001636
# Sequential Feature Selector    40,103,828,511.706619  0.233642       0.003011
# Select From Model              37,708,337,947.386711  0.279418       0.002060
# Polynomial Features            40,550,633,780.777458  0.225103       0.000904

# %%
ridge_df
# Out:
#                               explained variance score       mae score  \
# model
# Ridge Best Params                          0.250788002  149,461.433501
# Select From Model                          0.335361932  148,574.479146
# Sequential Feature Selector                0.176598345  152,551.269275
# Recursive Feature Elimination              0.335361932  148,574.479146
#
#                                            mse score  r2 score  mean fit time
# model
# Ridge Best Params              41,951,877,693.373276  0.198327       0.000000
# Select From Model              37,025,986,127.903168  0.292457       0.000000
# Sequential Feature Selector    46,009,427,143.237213  0.120789       0.001304
# Recursive Feature Elimination  37,025,986,127.903168  0.292457       0.000000
