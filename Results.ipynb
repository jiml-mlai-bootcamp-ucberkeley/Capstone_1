# %%
import pandas as pd

# %%
nj_latlong_decision_tree_df = pd.DataFrame({'model': ['Decision Tree Best Params',
  'Recursive Feature Elimination',
  'Sequential Feature Selector'],
 'explained variance score': ['0.525465856', '0.437692147', '0.300629820'],
 'mae score': ['161,667.633996', '168,477.035464', '197,605.994537'],
 'mse score': ['76,497,959,521.268478',
  '90,588,408,113.372543',
  '112,633,815,122.929260'],
 'r2 score': ['0.524659', '0.437104', '0.300119'],
 'mean fit time': [0.009398412704467774,
  0.033878517150878903,
  0.028026437759399413]}).set_index('model')

# %%
nj_one_zipcode_lasso_df = pd.DataFrame({'model': ['Lasso Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination'],
 'explained variance score': ['0.642435253',
  '0.632635341',
  '0.662632458',
  '0.632635341'],
 'mae score': ['137,358.113378',
  '138,911.240033',
  '134,201.068416',
  '138,911.240033'],
 'mse score': ['41,299,394,421.835884',
  '42,403,155,346.108559',
  '38,987,111,740.271225',
  '42,403,155,346.108559'],
 'r2 score': ['0.642098', '0.632533', '0.662137', '0.632533'],
 'mean fit time': [0.0038252830505371093,
  0.0028829097747802733,
  0.0029617786407470704,
  0.001983785629272461]}).set_index('model')

# %%
ny_latlong_decision_tree_df = pd.DataFrame({'model': ['Decision Tree Best Params',
  'Recursive Feature Elimination',
  'Sequential Feature Selector'],
 'explained variance score': ['0.697195714', '0.561655488', '0.532701790'],
 'mae score': ['238,327.094417', '277,522.727015', '279,925.113928'],
 'mse score': ['236,307,008,414.936371',
  '341,829,607,356.636108',
  '364,418,243,126.586853'],
 'r2 score': ['0.696972', '0.561655', '0.532688'],
 'mean fit time': [0.019043588638305665,
  0.05276641845703125,
  0.061376094818115234]}).set_index('model')

# %%
ny_one_zipcode_decision_tree_df = pd.DataFrame({'model': ['Decision Tree Best Params',
  'Recursive Feature Elimination',
  'Sequential Feature Selector'],
 'explained variance score': ['0.661461418', '0.832403592', '0.782233403'],
 'mae score': ['530,364.125397', '423,355.577778', '471,527.001058'],
 'mse score': ['747,909,920,375.919312',
  '370,211,522,923.479004',
  '475,785,667,513.888428'],
 'r2 score': ['0.645625', '0.824586', '0.774563'],
 'mean fit time': [0.001764678955078125,
  0.002796792984008789,
  0.0002106189727783203]}).set_index('model')

# %%
nj_latlong_decision_tree_df
# Out:
#                               explained variance score       mae score  \
# model
# Decision Tree Best Params                  0.525465856  161,667.633996
# Recursive Feature Elimination              0.437692147  168,477.035464
# Sequential Feature Selector                0.300629820  197,605.994537
#
#                                             mse score  r2 score  mean fit time
# model
# Decision Tree Best Params       76,497,959,521.268478  0.524659       0.009398
# Recursive Feature Elimination   90,588,408,113.372543  0.437104       0.033879
# Sequential Feature Selector    112,633,815,122.929260  0.300119       0.028026

# %%
nj_one_zipcode_lasso_df
# Out:
#                               explained variance score       mae score  \
# model
# Lasso Best Params                          0.642435253  137,358.113378
# Select From Model                          0.632635341  138,911.240033
# Sequential Feature Selector                0.662632458  134,201.068416
# Recursive Feature Elimination              0.632635341  138,911.240033
#
#                                            mse score  r2 score  mean fit time
# model
# Lasso Best Params              41,299,394,421.835884  0.642098       0.003825
# Select From Model              42,403,155,346.108559  0.632533       0.002883
# Sequential Feature Selector    38,987,111,740.271225  0.662137       0.002962
# Recursive Feature Elimination  42,403,155,346.108559  0.632533       0.001984

# %%
ny_latlong_decision_tree_df
# Out:
#                               explained variance score       mae score  \
# model
# Decision Tree Best Params                  0.697195714  238,327.094417
# Recursive Feature Elimination              0.561655488  277,522.727015
# Sequential Feature Selector                0.532701790  279,925.113928
#
#                                             mse score  r2 score  mean fit time
# model
# Decision Tree Best Params      236,307,008,414.936371  0.696972       0.019044
# Recursive Feature Elimination  341,829,607,356.636108  0.561655       0.052766
# Sequential Feature Selector    364,418,243,126.586853  0.532688       0.061376

# %%
ny_one_zipcode_decision_tree_df
# Out:
#                               explained variance score       mae score  \
# model
# Decision Tree Best Params                  0.661461418  530,364.125397
# Recursive Feature Elimination              0.832403592  423,355.577778
# Sequential Feature Selector                0.782233403  471,527.001058
#
#                                             mse score  r2 score  mean fit time
# model
# Decision Tree Best Params      747,909,920,375.919312  0.645625       0.001765
# Recursive Feature Elimination  370,211,522,923.479004  0.824586       0.002797
# Sequential Feature Selector    475,785,667,513.888428  0.774563       0.000211
