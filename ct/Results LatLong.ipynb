# %%
import pandas as pd

# %%
decision_tree_df = pd.DataFrame({'model': ['Decision Tree Best Params',
  'Recursive Feature Elimination',
  'Sequential Feature Selector'],
 'explained variance score': ['0.634791342', '0.591852430', '0.575732249'],
 'mae score': ['130,809.389604', '141,092.873611', '136,802.354167'],
 'mse score': ['52,807,310,507.427597',
  '59,262,435,804.406944',
  '61,371,080,590.487503'],
 'r2 score': ['0.634137', '0.589414', '0.574805'],
 'mean fit time': [0.004173851013183594,
  0.008319807052612305,
  0.0071489810943603516]}).set_index('model')

# %%
knn_df = pd.DataFrame({'model': ['KNN Best Params', 'Sequential Feature Selector'],
 'explained variance score': ['0.343461846', '0.562582899'],
 'mae score': ['180,492.520360', '143,169.910278'],
 'mse score': ['94,763,737,443.140488', '63,584,516,664.663940'],
 'r2 score': ['0.343451', '0.559469'],
 'mean fit time': [0.0034323692321777343, 0.0017270565032958985]}).set_index('model')

# %%
lasso_df = pd.DataFrame({'model': ['Lasso Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination'],
 'explained variance score': ['0.545612545',
  '0.491413303',
  '0.545272806',
  '0.491413303'],
 'mae score': ['160,524.050161',
  '172,752.328666',
  '160,563.340413',
  '172,752.328666'],
 'mse score': ['65,672,318,948.431274',
  '73,453,714,092.510513',
  '65,725,955,326.849693',
  '73,453,714,092.510513'],
 'r2 score': ['0.545004', '0.491093', '0.544633', '0.491093'],
 'mean fit time': [0.0054107666015625,
  0.0010268211364746094,
  0.0014832973480224609,
  0.0014412403106689453]}).set_index('model')

# %%
linear_df = pd.DataFrame({'model': ['Linear Regression',
  'Recursive Feature Elimination',
  'Sequential Feature Selector',
  'Select From Model'],
 'explained variance score': ['0.545617450',
  '0.491221574',
  '0.538254826',
  '0.491221574'],
 'mae score': ['160,520.289055',
  '172,847.691004',
  '160,676.841288',
  '172,847.691004'],
 'mse score': ['65,667,385,122.887230',
  '73,478,487,488.626022',
  '66,710,049,883.341255',
  '73,478,487,488.626022'],
 'r2 score': ['0.545039', '0.490921', '0.537815', '0.490921'],
 'mean fit time': [0.005930471420288086,
  0.004866313934326172,
  0.003883028030395508,
  0.0014881134033203126]}).set_index('model')

# %%
ridge_df = pd.DataFrame({'model': ['Ridge Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination'],
 'explained variance score': ['0.545612545',
  '0.491320646',
  '0.545143924',
  '0.491320646'],
 'mae score': ['160,524.050161',
  '172,549.271661',
  '160,357.176579',
  '172,549.271661'],
 'mse score': ['65,672,318,948.447388',
  '73,466,051,698.183502',
  '65,743,200,349.344940',
  '73,466,051,698.183502'],
 'r2 score': ['0.545004', '0.491007', '0.544513', '0.491007'],
 'mean fit time': [0.0008847236633300782,
  0.0021860599517822266,
  0.0018239021301269531,
  0.001645660400390625]}).set_index('model')

# %%
decision_tree_df
# Out:
#                               explained variance score       mae score  \
# model
# Decision Tree Best Params                  0.634791342  130,809.389604
# Recursive Feature Elimination              0.591852430  141,092.873611
# Sequential Feature Selector                0.575732249  136,802.354167
#
#                                            mse score  r2 score  mean fit time
# model
# Decision Tree Best Params      52,807,310,507.427597  0.634137       0.004174
# Recursive Feature Elimination  59,262,435,804.406944  0.589414       0.008320
# Sequential Feature Selector    61,371,080,590.487503  0.574805       0.007149

# %%
knn_df
# Out:
#                             explained variance score       mae score  \
# model
# KNN Best Params                          0.343461846  180,492.520360
# Sequential Feature Selector              0.562582899  143,169.910278
#
#                                          mse score  r2 score  mean fit time
# model
# KNN Best Params              94,763,737,443.140488  0.343451       0.003432
# Sequential Feature Selector  63,584,516,664.663940  0.559469       0.001727

# %%
lasso_df
# Out:
#                               explained variance score       mae score  \
# model
# Lasso Best Params                          0.545612545  160,524.050161
# Select From Model                          0.491413303  172,752.328666
# Sequential Feature Selector                0.545272806  160,563.340413
# Recursive Feature Elimination              0.491413303  172,752.328666
#
#                                            mse score  r2 score  mean fit time
# model
# Lasso Best Params              65,672,318,948.431274  0.545004       0.005411
# Select From Model              73,453,714,092.510513  0.491093       0.001027
# Sequential Feature Selector    65,725,955,326.849693  0.544633       0.001483
# Recursive Feature Elimination  73,453,714,092.510513  0.491093       0.001441

# %%
linear_df
# Out:
#                               explained variance score       mae score  \
# model
# Linear Regression                          0.545617450  160,520.289055
# Recursive Feature Elimination              0.491221574  172,847.691004
# Sequential Feature Selector                0.538254826  160,676.841288
# Select From Model                          0.491221574  172,847.691004
#
#                                            mse score  r2 score  mean fit time
# model
# Linear Regression              65,667,385,122.887230  0.545039       0.005930
# Recursive Feature Elimination  73,478,487,488.626022  0.490921       0.004866
# Sequential Feature Selector    66,710,049,883.341255  0.537815       0.003883
# Select From Model              73,478,487,488.626022  0.490921       0.001488

# %%
ridge_df
# Out:
#                               explained variance score       mae score  \
# model
# Ridge Best Params                          0.545612545  160,524.050161
# Select From Model                          0.491320646  172,549.271661
# Sequential Feature Selector                0.545143924  160,357.176579
# Recursive Feature Elimination              0.491320646  172,549.271661
#
#                                            mse score  r2 score  mean fit time
# model
# Ridge Best Params              65,672,318,948.447388  0.545004       0.000885
# Select From Model              73,466,051,698.183502  0.491007       0.002186
# Sequential Feature Selector    65,743,200,349.344940  0.544513       0.001824
# Recursive Feature Elimination  73,466,051,698.183502  0.491007       0.001646
