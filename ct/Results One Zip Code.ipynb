# %%
import pandas as pd

# %%
decision_tree_df = pd.DataFrame({'model': ['Decision Tree',
  'Recursive Feature Elimination',
  'Sequential Feature Selector'],
 'explained variance score': ['0.360339984', '0.693073182', '0.326441541'],
 'mae score': ['99,251.600165', '68,369.230769', '108,238.384615'],
 'mse score': ['17,589,237,604.841423',
  '9,471,603,076.923077',
  '18,598,253,830.846153'],
 'r2 score': ['0.359807', '0.655263', '0.323082'],
 'mean fit time': [0.0006387710571289062,
  0.0007283687591552734,
  0.002964162826538086]}).set_index('model')

# %%
knn_df = pd.DataFrame({'model': ['KNN Best Params', 'Sequential Feature Selector'],
 'explained variance score': ['0.343461846', '0.562582899'],
 'mae score': ['180,492.520360', '143,169.910278'],
 'mse score': ['94,763,737,443.140488', '63,584,516,664.663940'],
 'r2 score': ['0.343451', '0.559469'],
 'mean fit time': [0.0034323692321777343, 0.0017270565032958985]}).set_index('model')

# %%
lasso_df = pd.DataFrame({'model': ['Lasso Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination'],
 'explained variance score': ['0.499806806',
  '0.487768088',
  '0.672189931',
  '0.487768088'],
 'mae score': ['93,587.787434',
  '88,097.290782',
  '71,360.025307',
  '88,097.290782'],
 'mse score': ['13,816,190,720.018505',
  '14,093,628,058.990791',
  '9,121,252,152.465351',
  '14,093,628,058.990791'],
 'r2 score': ['0.497134', '0.487036', '0.668015', '0.487036'],
 'mean fit time': [0.002414035797119141,
  0.0022910118103027345,
  0.0017217159271240234,
  0.0012124061584472656]}).set_index('model')

# %%
linear_df = pd.DataFrame({'model': ['Linear Regression',
  'Recursive Feature Elimination',
  'Sequential Feature Selector',
  'Select From Model',
  'Polynomial Features'],
 'explained variance score': ['0.689954718',
  '0.504236692',
  '0.815296238',
  '0.688626917',
  '0.674882454'],
 'mae score': ['70,475.213050',
  '87,374.793340',
  '54,856.746653',
  '65,559.937918',
  '71,881.239441'],
 'mse score': ['8,662,450,979.779259',
  '13,696,829,661.152462',
  '5,756,563,544.726032',
  '9,332,171,936.151722',
  '8,998,034,093.714491'],
 'r2 score': ['0.684714', '0.501478', '0.790479', '0.660338', '0.672500'],
 'mean fit time': [0.004237937927246094,
  0.0012464046478271485,
  0.0029698848724365235,
  0.0026589393615722655,
  0.004964637756347656]}).set_index('model')

# %%
ridge_df = pd.DataFrame({'model': ['Ridge Best Params',
  'Select From Model',
  'Sequential Feature Selector',
  'Recursive Feature Elimination'],
 'explained variance score': ['0.589079714',
  '0.367342259',
  '0.609402198',
  '0.367342259'],
 'mae score': ['82,406.744299',
  '100,234.159979',
  '80,102.553486',
  '100,234.159979'],
 'mse score': ['11,320,078,865.568382',
  '17,383,051,689.631622',
  '10,818,433,331.470411',
  '17,383,051,689.631622'],
 'r2 score': ['0.587985', '0.367311', '0.606243', '0.367311'],
 'mean fit time': [0.0020918846130371094,
  0.001301145553588867,
  0.0008547306060791016,
  0.0007640838623046875]}).set_index('model')

# %%
decision_tree_df
# Out:
#                               explained variance score       mae score  \
# model
# Decision Tree                              0.360339984   99,251.600165
# Recursive Feature Elimination              0.693073182   68,369.230769
# Sequential Feature Selector                0.326441541  108,238.384615
#
#                                            mse score  r2 score  mean fit time
# model
# Decision Tree                  17,589,237,604.841423  0.359807       0.000639
# Recursive Feature Elimination   9,471,603,076.923077  0.655263       0.000728
# Sequential Feature Selector    18,598,253,830.846153  0.323082       0.002964

# %%
knn_df
# Out:
#                             explained variance score       mae score  \
# model
# KNN Best Params                          0.343461846  180,492.520360
# Sequential Feature Selector              0.562582899  143,169.910278
#
#                                          mse score  r2 score  mean fit time
# model
# KNN Best Params              94,763,737,443.140488  0.343451       0.003432
# Sequential Feature Selector  63,584,516,664.663940  0.559469       0.001727

# %%
lasso_df
# Out:
#                               explained variance score      mae score  \
# model
# Lasso Best Params                          0.499806806  93,587.787434
# Select From Model                          0.487768088  88,097.290782
# Sequential Feature Selector                0.672189931  71,360.025307
# Recursive Feature Elimination              0.487768088  88,097.290782
#
#                                            mse score  r2 score  mean fit time
# model
# Lasso Best Params              13,816,190,720.018505  0.497134       0.002414
# Select From Model              14,093,628,058.990791  0.487036       0.002291
# Sequential Feature Selector     9,121,252,152.465351  0.668015       0.001722
# Recursive Feature Elimination  14,093,628,058.990791  0.487036       0.001212

# %%
linear_df
# Out:
#                               explained variance score      mae score  \
# model
# Linear Regression                          0.689954718  70,475.213050
# Recursive Feature Elimination              0.504236692  87,374.793340
# Sequential Feature Selector                0.815296238  54,856.746653
# Select From Model                          0.688626917  65,559.937918
# Polynomial Features                        0.674882454  71,881.239441
#
#                                            mse score  r2 score  mean fit time
# model
# Linear Regression               8,662,450,979.779259  0.684714       0.004238
# Recursive Feature Elimination  13,696,829,661.152462  0.501478       0.001246
# Sequential Feature Selector     5,756,563,544.726032  0.790479       0.002970
# Select From Model               9,332,171,936.151722  0.660338       0.002659
# Polynomial Features             8,998,034,093.714491  0.672500       0.004965

# %%
ridge_df
# Out:
#                               explained variance score       mae score  \
# model
# Ridge Best Params                          0.589079714   82,406.744299
# Select From Model                          0.367342259  100,234.159979
# Sequential Feature Selector                0.609402198   80,102.553486
# Recursive Feature Elimination              0.367342259  100,234.159979
#
#                                            mse score  r2 score  mean fit time
# model
# Ridge Best Params              11,320,078,865.568382  0.587985       0.002092
# Select From Model              17,383,051,689.631622  0.367311       0.001301
# Sequential Feature Selector    10,818,433,331.470411  0.606243       0.000855
# Recursive Feature Elimination  17,383,051,689.631622  0.367311       0.000764
